# %%
# %matplotlib inline

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets

# %%
from __future__ import print_function, division

import os
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()   # interactive mode

# %%
print(torch.__version__)
# Out:
# 0.4.0

# %%
print(os.path.join(data_dir, 'DIV2K_valid_LR_bicubic'))
print(os.path.join(data_dir, 'DIV2K_valid_LR_bicubic'))
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['DIV2K_valid_LR_bicubic', 'DIV2K_valid_HR']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=1,
                                             shuffle=False, num_workers=0)
              for x in ['DIV2K_valid_LR_bicubic', 'DIV2K_valid_LR_bicubic']}
test_batch = 1

dataset_sizes = {x: len(image_datasets[x]) for x in ['DIV2K_valid_LR_bicubic', 'DIV2K_valid_LR_bicubic']}

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

# %%
import glob
from PIL import Image

data_dir = '../../../data/benchmark/valid'
img_dir = {'hr': 'HR/*', 'lr': 'LR_bicubic/X2/*'}

image_datasets = {x: sorted(glob.glob(os.path.join(data_dir, img_dir[x])))
                  for x in ['hr', 'lr']}
print(image_datasets['hr'])
print(image_datasets['lr'])

for image in image_datasets['lr']:
    img = np.asarray(Image.open(image))
    img = np.moveaxis(img, -1, 0)
    #print(img.shape)
    img = torch.from_numpy(img)
    #print(img.size())
    img = img.unsqueeze(0)
    print(img.size())
    img = img.to(dtype=torch.float32, device='cuda')
    print(img.size())
    
    pytorch_model_name = 'edsr.model' #self.args.ngraph
    pytorch_edsr_model = torch.load(pytorch_model_name)
    # dummy_input = torch.randn_like(img, device='cuda')
    # dummy_input = torch.randn_like(lr, device='cuda')                      
    # dummy_input = torch.randn(batch_size, 3, 224, 224, device='cuda')
    print(dummy_input.size())
    edsr_onnx_filename = '{}.onnx'.format(pytorch_model_name)
    #torch.onnx.export(pytorch_edsr_model, dummy_input, edsr_onnx_filename, export_params=True, verbose=False, training=False)
    torch.onnx.export(pytorch_edsr_model, img, edsr_onnx_filename, export_params=True, verbose=False, training=False)
# Out:
# ['../../../data/benchmark/valid/HR/0801.png', '../../../data/benchmark/valid/HR/0802.png', '../../../data/benchmark/valid/HR/0803.png', '../../../data/benchmark/valid/HR/0804.png', '../../../data/benchmark/valid/HR/0805.png', '../../../data/benchmark/valid/HR/0806.png', '../../../data/benchmark/valid/HR/0807.png', '../../../data/benchmark/valid/HR/0808.png', '../../../data/benchmark/valid/HR/0809.png', '../../../data/benchmark/valid/HR/0810.png', '../../../data/benchmark/valid/HR/0811.png', '../../../data/benchmark/valid/HR/0812.png', '../../../data/benchmark/valid/HR/0813.png', '../../../data/benchmark/valid/HR/0814.png', '../../../data/benchmark/valid/HR/0815.png', '../../../data/benchmark/valid/HR/0816.png', '../../../data/benchmark/valid/HR/0817.png', '../../../data/benchmark/valid/HR/0818.png', '../../../data/benchmark/valid/HR/0819.png', '../../../data/benchmark/valid/HR/0820.png', '../../../data/benchmark/valid/HR/0821.png', '../../../data/benchmark/valid/HR/0822.png', '../../../data/benchmark/valid/HR/0823.png', '../../../data/benchmark/valid/HR/0824.png', '../../../data/benchmark/valid/HR/0825.png', '../../../data/benchmark/valid/HR/0826.png', '../../../data/benchmark/valid/HR/0827.png', '../../../data/benchmark/valid/HR/0828.png', '../../../data/benchmark/valid/HR/0829.png', '../../../data/benchmark/valid/HR/0830.png', '../../../data/benchmark/valid/HR/0831.png', '../../../data/benchmark/valid/HR/0832.png', '../../../data/benchmark/valid/HR/0833.png', '../../../data/benchmark/valid/HR/0834.png', '../../../data/benchmark/valid/HR/0835.png', '../../../data/benchmark/valid/HR/0836.png', '../../../data/benchmark/valid/HR/0837.png', '../../../data/benchmark/valid/HR/0838.png', '../../../data/benchmark/valid/HR/0839.png', '../../../data/benchmark/valid/HR/0840.png', '../../../data/benchmark/valid/HR/0841.png', '../../../data/benchmark/valid/HR/0842.png', '../../../data/benchmark/valid/HR/0843.png', '../../../data/benchmark/valid/HR/0844.png', '../../../data/benchmark/valid/HR/0845.png', '../../../data/benchmark/valid/HR/0846.png', '../../../data/benchmark/valid/HR/0847.png', '../../../data/benchmark/valid/HR/0848.png', '../../../data/benchmark/valid/HR/0849.png', '../../../data/benchmark/valid/HR/0850.png', '../../../data/benchmark/valid/HR/0851.png', '../../../data/benchmark/valid/HR/0852.png', '../../../data/benchmark/valid/HR/0853.png', '../../../data/benchmark/valid/HR/0854.png', '../../../data/benchmark/valid/HR/0855.png', '../../../data/benchmark/valid/HR/0856.png', '../../../data/benchmark/valid/HR/0857.png', '../../../data/benchmark/valid/HR/0858.png', '../../../data/benchmark/valid/HR/0859.png', '../../../data/benchmark/valid/HR/0860.png', '../../../data/benchmark/valid/HR/0861.png', '../../../data/benchmark/valid/HR/0862.png', '../../../data/benchmark/valid/HR/0863.png', '../../../data/benchmark/valid/HR/0864.png', '../../../data/benchmark/valid/HR/0865.png', '../../../data/benchmark/valid/HR/0866.png', '../../../data/benchmark/valid/HR/0867.png', '../../../data/benchmark/valid/HR/0868.png', '../../../data/benchmark/valid/HR/0869.png', '../../../data/benchmark/valid/HR/0870.png', '../../../data/benchmark/valid/HR/0871.png', '../../../data/benchmark/valid/HR/0872.png', '../../../data/benchmark/valid/HR/0873.png', '../../../data/benchmark/valid/HR/0874.png', '../../../data/benchmark/valid/HR/0875.png', '../../../data/benchmark/valid/HR/0876.png', '../../../data/benchmark/valid/HR/0877.png', '../../../data/benchmark/valid/HR/0878.png', '../../../data/benchmark/valid/HR/0879.png', '../../../data/benchmark/valid/HR/0880.png', '../../../data/benchmark/valid/HR/0881.png', '../../../data/benchmark/valid/HR/0882.png', '../../../data/benchmark/valid/HR/0883.png', '../../../data/benchmark/valid/HR/0884.png', '../../../data/benchmark/valid/HR/0885.png', '../../../data/benchmark/valid/HR/0886.png', '../../../data/benchmark/valid/HR/0887.png', '../../../data/benchmark/valid/HR/0888.png', '../../../data/benchmark/valid/HR/0889. ...
# ['../../../data/benchmark/valid/LR_bicubic/X2/0801x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0802x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0803x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0804x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0805x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0806x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0807x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0808x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0809x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0810x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0811x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0812x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0813x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0814x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0815x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0816x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0817x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0818x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0819x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0820x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0821x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0822x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0823x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0824x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0825x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0826x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0827x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0828x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0829x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0830x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0831x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0832x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0833x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0834x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0835x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0836x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0837x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0838x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0839x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0840x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0841x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0842x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0843x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0844x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0845x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0846x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0847x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0848x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0849x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0850x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0851x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0852x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0853x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0854x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0855x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0856x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0857x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0858x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0859x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0860x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0861x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0862x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0863x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0864x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0865x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0866x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0867x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0868x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0869x2.png ...
# torch.Size([1, 3, 678, 1020])
# torch.Size([1, 3, 678, 1020])
# torch.Size([1, 3, 678, 1020])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-329abe537ce4> in <module>
#      29     edsr_onnx_filename = '{}.onnx'.format(pytorch_model_name)
#      30     #torch.onnx.export(pytorch_edsr_model, dummy_input, edsr_onnx_filename, export_params=True, verbose=False, training=False)
# ---> 31     torch.onnx.export(pytorch_edsr_model, img, edsr_onnx_filename, export_params=True, verbose=False, training=False)
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/onnx/__init__.py in export(*args, **kwargs)
#      23 def export(*args, **kwargs):
#      24     from torch.onnx import utils
# ---> 25     return utils.export(*args, **kwargs)
#      26
#      27
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/onnx/utils.py in export(model, args, f, export_params, verbose, training, input_names, output_names, aten)
#      82             as ATen ops.
#      83     """
# ---> 84     _export(model, args, f, export_params, verbose, training, input_names, output_names)
#      85
#      86
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/onnx/utils.py in _export(model, args, f, export_params, verbose, training, input_names, output_names, aten, export_type)
#     132     # training mode was.)
#     133     with set_training(model, training):
# --> 134         trace, torch_out = torch.jit.get_trace_graph(model, args)
#     135
#     136     if orig_state_dict_keys != _unique_state_dict(model).keys():
#
# /usr/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/onnx/utils.py in set_training(model, mode)
#      36         model.train(mode)
#      37     try:
# ---> 38         yield
#      39     finally:
#      40         if old_mode != mode:
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/onnx/utils.py in _export(model, args, f, export_params, verbose, training, input_names, output_names, aten, export_type)
#     132     # training mode was.)
#     133     with set_training(model, training):
# --> 134         trace, torch_out = torch.jit.get_trace_graph(model, args)
#     135
#     136     if orig_state_dict_keys != _unique_state_dict(model).keys():
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/jit/__init__.py in get_trace_graph(f, args, kwargs, nderivs)
#     253     if not isinstance(args, tuple):
#     254         args = (args,)
# --> 255     return LegacyTracedModule(f, nderivs=nderivs)(*args, **kwargs)
#     256
#     257
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             hook(self, input)
#     488         if torch.jit._tracing:
# --> 489             result = self._slow_forward(*input, **kwargs)
#     490         else:
#     491             result = self.forward(*input, **kwargs)
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in _slow_forward(self, *input, **kwargs)
#     467         tracing_state = torch.jit.get_tracing_state(input_vars)
#     468         if not tracing_state:
# --> 469             return self.forward(*input, **kwargs)
#     470         if not hasattr(tracing_state, '_traced_module_stack'):
#     471             tracing_state._traced_module_stack = []
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/jit/__init__.py in forward(self, *args)
#     286         _tracing = True
#     287         trace_inputs = _unflatten(all_trace_inputs[:len(in_vars)], in_desc)
# --> 288         out = self.inner(*trace_inputs)
#     289         out_vars, _ = _flatten(out)
#     290         _tracing = False
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             hook(self, input)
#     488         if torch.jit._tracing:
# --> 489             result = self._slow_forward(*input, **kwargs)
#     490         else:
#     491             result = self.forward(*input, **kwargs)
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in _slow_forward(self, *input, **kwargs)
#     477         tracing_state._traced_module_stack.append(self)
#     478         try:
# --> 479             result = self.forward(*input, **kwargs)
#     480         finally:
#     481             tracing_state.pop_scope()
#
# /home/ccma/n1p1/home/ccma/Chilung/edsr040/EDSR-PyTorch/src/model/edsr.py in forward(self, x)
#      57         x = self.head(x)
#      58
# ---> 59         res = self.body(x)
#      60         res += x
#      61
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             hook(self, input)
#     488         if torch.jit._tracing:
# --> 489             result = self._slow_forward(*input, **kwargs)
#     490         else:
#     491             result = self.forward(*input, **kwargs)
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in _slow_forward(self, *input, **kwargs)
#     477         tracing_state._traced_module_stack.append(self)
#     478         try:
# --> 479             result = self.forward(*input, **kwargs)
#     480         finally:
#     481             tracing_state.pop_scope()
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             hook(self, input)
#     488         if torch.jit._tracing:
# --> 489             result = self._slow_forward(*input, **kwargs)
#     490         else:
#     491             result = self.forward(*input, **kwargs)
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in _slow_forward(self, *input, **kwargs)
#     477         tracing_state._traced_module_stack.append(self)
#     478         try:
# --> 479             result = self.forward(*input, **kwargs)
#     480         finally:
#     481             tracing_state.pop_scope()
#
# /home/ccma/n1p1/home/ccma/Chilung/edsr040/EDSR-PyTorch/src/model/common.py in forward(self, x)
#      47
#      48     def forward(self, x):
# ---> 49         res = self.body(x).mul(self.res_scale)
#      50         res += x
#      51
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             hook(self, input)
#     488         if torch.jit._tracing:
# --> 489             result = self._slow_forward(*input, **kwargs)
#     490         else:
#     491             result = self.forward(*input, **kwargs)
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in _slow_forward(self, *input, **kwargs)
#     477         tracing_state._traced_module_stack.append(self)
#     478         try:
# --> 479             result = self.forward(*input, **kwargs)
#     480         finally:
#     481             tracing_state.pop_scope()
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             hook(self, input)
#     488         if torch.jit._tracing:
# --> 489             result = self._slow_forward(*input, **kwargs)
#     490         else:
#     491             result = self.forward(*input, **kwargs)
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/module.py in _slow_forward(self, *input, **kwargs)
#     477         tracing_state._traced_module_stack.append(self)
#     478         try:
# --> 479             result = self.forward(*input, **kwargs)
#     480         finally:
#     481             tracing_state.pop_scope()
#
# /home/ccma/n1p1/home/ccma/Chilung/1022/distiller/venv/lib/python3.5/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# RuntimeError: cuda runtime error (2) : out of memory at /pytorch/aten/src/THC/generic/THCStorage.cu:58

# %%
import glob
from PIL import Image

data_dir = '../../../data/benchmark/valid'
img_dir = {'hr': 'HR/*', 'lr': 'LR_bicubic/X2/*'}

image_datasets = {x: sorted(glob.glob(os.path.join(data_dir, img_dir[x])))
                  for x in ['hr', 'lr']}
print(image_datasets['hr'])
print(image_datasets['lr'])

for image in image_datasets['lr']:
    img = np.asarray(Image.open(image))
    img = np.moveaxis(img, -1, 0)
    print(img.shape)
    img = torch.from_numpy(img)
    
    pytorch_model_name = 'edsr.model' #self.args.ngraph
    pytorch_edsr_model = torch.load(pytorch_model_name)
    dummy_input = torch.randn_like(img, device='cuda')
    edsr_onnx_filename = '{}.onnx'.format(pytorch_model_name)
    torch.onnx.export(pytorch_edsr_model, dummy_input, edsr_onnx_filename, export_params=True, verbose=False, training=False)

    import os
    import onnx

    edsr_onnx_model = onnx.load(edsr_onnx_filename)

    from ngraph_onnx.onnx_importer.importer import import_onnx_model
    ng_models = import_onnx_model(edsr_onnx_model)

    import ngraph as ng
    ng_model = ng_models[0]
    runtime = ng.runtime(backend_name='CPU')
    edsr_ng_model = runtime.computation(ng_model['output'], *ng_model['inputs'])

    sr = edsr_ng_model(img, idx_scale)
    sr = torch.from_numpy(sr)
# Out:
# ['../../../data/benchmark/valid/HR/0801.png', '../../../data/benchmark/valid/HR/0802.png', '../../../data/benchmark/valid/HR/0803.png', '../../../data/benchmark/valid/HR/0804.png', '../../../data/benchmark/valid/HR/0805.png', '../../../data/benchmark/valid/HR/0806.png', '../../../data/benchmark/valid/HR/0807.png', '../../../data/benchmark/valid/HR/0808.png', '../../../data/benchmark/valid/HR/0809.png', '../../../data/benchmark/valid/HR/0810.png', '../../../data/benchmark/valid/HR/0811.png', '../../../data/benchmark/valid/HR/0812.png', '../../../data/benchmark/valid/HR/0813.png', '../../../data/benchmark/valid/HR/0814.png', '../../../data/benchmark/valid/HR/0815.png', '../../../data/benchmark/valid/HR/0816.png', '../../../data/benchmark/valid/HR/0817.png', '../../../data/benchmark/valid/HR/0818.png', '../../../data/benchmark/valid/HR/0819.png', '../../../data/benchmark/valid/HR/0820.png', '../../../data/benchmark/valid/HR/0821.png', '../../../data/benchmark/valid/HR/0822.png', '../../../data/benchmark/valid/HR/0823.png', '../../../data/benchmark/valid/HR/0824.png', '../../../data/benchmark/valid/HR/0825.png', '../../../data/benchmark/valid/HR/0826.png', '../../../data/benchmark/valid/HR/0827.png', '../../../data/benchmark/valid/HR/0828.png', '../../../data/benchmark/valid/HR/0829.png', '../../../data/benchmark/valid/HR/0830.png', '../../../data/benchmark/valid/HR/0831.png', '../../../data/benchmark/valid/HR/0832.png', '../../../data/benchmark/valid/HR/0833.png', '../../../data/benchmark/valid/HR/0834.png', '../../../data/benchmark/valid/HR/0835.png', '../../../data/benchmark/valid/HR/0836.png', '../../../data/benchmark/valid/HR/0837.png', '../../../data/benchmark/valid/HR/0838.png', '../../../data/benchmark/valid/HR/0839.png', '../../../data/benchmark/valid/HR/0840.png', '../../../data/benchmark/valid/HR/0841.png', '../../../data/benchmark/valid/HR/0842.png', '../../../data/benchmark/valid/HR/0843.png', '../../../data/benchmark/valid/HR/0844.png', '../../../data/benchmark/valid/HR/0845.png', '../../../data/benchmark/valid/HR/0846.png', '../../../data/benchmark/valid/HR/0847.png', '../../../data/benchmark/valid/HR/0848.png', '../../../data/benchmark/valid/HR/0849.png', '../../../data/benchmark/valid/HR/0850.png', '../../../data/benchmark/valid/HR/0851.png', '../../../data/benchmark/valid/HR/0852.png', '../../../data/benchmark/valid/HR/0853.png', '../../../data/benchmark/valid/HR/0854.png', '../../../data/benchmark/valid/HR/0855.png', '../../../data/benchmark/valid/HR/0856.png', '../../../data/benchmark/valid/HR/0857.png', '../../../data/benchmark/valid/HR/0858.png', '../../../data/benchmark/valid/HR/0859.png', '../../../data/benchmark/valid/HR/0860.png', '../../../data/benchmark/valid/HR/0861.png', '../../../data/benchmark/valid/HR/0862.png', '../../../data/benchmark/valid/HR/0863.png', '../../../data/benchmark/valid/HR/0864.png', '../../../data/benchmark/valid/HR/0865.png', '../../../data/benchmark/valid/HR/0866.png', '../../../data/benchmark/valid/HR/0867.png', '../../../data/benchmark/valid/HR/0868.png', '../../../data/benchmark/valid/HR/0869.png', '../../../data/benchmark/valid/HR/0870.png', '../../../data/benchmark/valid/HR/0871.png', '../../../data/benchmark/valid/HR/0872.png', '../../../data/benchmark/valid/HR/0873.png', '../../../data/benchmark/valid/HR/0874.png', '../../../data/benchmark/valid/HR/0875.png', '../../../data/benchmark/valid/HR/0876.png', '../../../data/benchmark/valid/HR/0877.png', '../../../data/benchmark/valid/HR/0878.png', '../../../data/benchmark/valid/HR/0879.png', '../../../data/benchmark/valid/HR/0880.png', '../../../data/benchmark/valid/HR/0881.png', '../../../data/benchmark/valid/HR/0882.png', '../../../data/benchmark/valid/HR/0883.png', '../../../data/benchmark/valid/HR/0884.png', '../../../data/benchmark/valid/HR/0885.png', '../../../data/benchmark/valid/HR/0886.png', '../../../data/benchmark/valid/HR/0887.png', '../../../data/benchmark/valid/HR/0888.png', '../../../data/benchmark/valid/HR/0889. ...
# ['../../../data/benchmark/valid/LR_bicubic/X2/0801x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0802x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0803x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0804x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0805x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0806x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0807x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0808x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0809x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0810x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0811x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0812x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0813x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0814x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0815x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0816x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0817x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0818x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0819x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0820x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0821x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0822x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0823x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0824x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0825x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0826x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0827x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0828x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0829x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0830x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0831x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0832x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0833x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0834x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0835x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0836x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0837x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0838x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0839x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0840x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0841x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0842x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0843x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0844x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0845x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0846x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0847x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0848x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0849x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0850x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0851x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0852x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0853x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0854x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0855x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0856x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0857x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0858x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0859x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0860x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0861x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0862x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0863x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0864x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0865x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0866x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0867x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0868x2.png', '../../../data/benchmark/valid/LR_bicubic/X2/0869x2.png ...
# (3, 678, 1020)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-9afe145c8f23> in <module>
#      18     pytorch_model_name = 'edsr.model' #self.args.ngraph
#      19     pytorch_edsr_model = torch.load(pytorch_model_name)
# ---> 20     dummy_input = torch.randn_like(img, device='cuda')
#      21     edsr_onnx_filename = '{}.onnx'.format(pytorch_model_name)
#      22     torch.onnx.export(pytorch_edsr_model, dummy_input, edsr_onnx_filename, export_params=True, verbose=False, training=False)
#
# RuntimeError: normal_ is not implemented for type torch.cuda.ByteTensor

# %%
data_transforms = {
    'DIV2K_valid_HR': transforms.Compose([
        transforms.ToTensor(),
    ]),
    'DIV2K_valid_LR_bicubic': transforms.Compose([
        transforms.ToTensor(),
    ]),
}


print(os.path.join(data_dir, 'DIV2K_valid_LR_bicubic'))
print(os.path.join(data_dir, 'DIV2K_valid_LR_bicubic'))
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['DIV2K_valid_LR_bicubic', 'DIV2K_valid_HR']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=1,
                                             shuffle=False, num_workers=0)
              for x in ['DIV2K_valid_LR_bicubic', 'DIV2K_valid_LR_bicubic']}
test_batch = 1

dataset_sizes = {x: len(image_datasets[x]) for x in ['DIV2K_valid_LR_bicubic', 'DIV2K_valid_LR_bicubic']}

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# ../data/DIV2K/DIV2K_valid_LR_bicubic
# ../data/DIV2K/DIV2K_valid_LR_bicubic
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-5b7e9ab22108> in <module>
#      13 image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
#      14                                           data_transforms[x])
# ---> 15                   for x in ['DIV2K_valid_LR_bicubic', 'DIV2K_valid_HR']}
#      16 dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=1,
#      17                                              shuffle=False, num_workers=0)
#
# <ipython-input-22-5b7e9ab22108> in <dictcomp>(.0)
#      13 image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
#      14                                           data_transforms[x])
# ---> 15                   for x in ['DIV2K_valid_LR_bicubic', 'DIV2K_valid_HR']}
#      16 dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=1,
#      17                                              shuffle=False, num_workers=0)
#
# /home/ccma/n1p1/home/ccma/Chilung/lab5-venv/lib/python3.5/site-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader)
#     176         super(ImageFolder, self).__init__(root, loader, IMG_EXTENSIONS,
#     177                                           transform=transform,
# --> 178                                           target_transform=target_transform)
#     179         self.imgs = self.samples
#
# /home/ccma/n1p1/home/ccma/Chilung/lab5-venv/lib/python3.5/site-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform)
#      77         if len(samples) == 0:
#      78             raise(RuntimeError("Found 0 files in subfolders of: " + root + "\n"
# ---> 79                                "Supported extensions are: " + ",".join(extensions)))
#      80
#      81         self.root = root
#
# RuntimeError: Found 0 files in subfolders of: ../data/DIV2K/DIV2K_valid_HR
# Supported extensions are: .jpg,.jpeg,.png,.ppm,.bmp,.pgm,.tif

# %%
print(dataloaders)
# Out:
# {'val': <torch.utils.data.dataloader.DataLoader object at 0x7fee33840cf8>, 'train': <torch.utils.data.dataloader.DataLoader object at 0x7fee33840ef0>, 'test': <torch.utils.data.dataloader.DataLoader object at 0x7fee33840c18>}

# %% [markdown]
# Visualize a few images
# ^^^^^^^^^^^^^^^^^^^^^^
# Let's visualize a few training images so as to understand the data
# augmentations.

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.5548, 0.4508, 0.3435])
    std = np.array([0.2281, 0.2384, 0.2376])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val':
                scheduler.step(epoch_loss)
                if epoch_acc > best_acc:
                    best_acc = epoch_acc
                    best_model_wts = copy.deepcopy(model.state_dict())
            
        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
classes = ('Bread', 'DairyProduct', 'Dessert', 'Egg', 'Friedfood',
    'Meat', 'Noodles-Pasta', 'Rice', 'Seafood', 'Soup', 'Vegetable-Fruit')

# %%
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 11)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.5 every 10 epochs
exp_lr_scheduler = lr_scheduler.ReduceLROnPlateau(
    optimizer_ft, mode='min', patience=6, verbose=True)
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.5)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=1)
# Out:
# Epoch 0/0
# ----------
# train Loss: 1.4795 Acc: 0.5265
# val Loss: 0.7857 Acc: 0.7589
#
# Training complete in 2m 52s
# Best val Acc: 0.758892

# %%
visualize_model(model_ft)

# %%
print('==> Saving model..')
#save entire model
model_name = './model-lab5-pytorch-0.4.0-resnet18-food11-' + str(time.time()) + '.pt'
torch.save(model_ft, model_name)
print('Finished Saving')
# Out:
# ==> Saving model..
# Finished Saving

# %%
model_name = './model-lab5-pytorch-0.4.0-resnet18-food11-1544328065.9809835.pt'

# %%
print('==> Loading model..')
model_ft = torch.load(model_name)
print('Finished Loading')
# Out:
# ==> Loading model..
# Finished Loading

# %%
######################
# Test the Model
######################
def test(t_data, device):
    print('test data set: %s' %(t_data))
          
    correct = 0
    total = 0
    running_loss = 0.0

    class_correct = list(0. for i in range(11))
    class_total = list(0. for i in range(11))

    model_ft.to(device)
    with torch.no_grad():
        for data in dataloaders[t_data]:
            images, labels = data

            #if device == 'cuda':
            #    images = images.cuda(0)
            #    labels = labels.cuda(0)
            #else:
            #    images = images.cpu()
            #    labels = labels.cpu()
            images = images.to(device)
            labels = labels.to(device)

            outputs = model_ft(images)
            _, predicted = torch.max(outputs, 1)
        
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            loss = criterion(outputs, labels)
            running_loss += loss.item()

            c = (predicted == labels).squeeze()
            #print(predicted)
            #print(labels.size(0))
            #print(c)
            for i in range(labels.size(0)):
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1

    print('Accuracy of the network on the %d test images: %.2f%%, and loss is: %.3f'
          % (total, 100 * correct / total, running_loss / total))

    for i in range(11):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))

# %%
for test_batch in [2, 4, 8, 16, 32, 64, 128, 256]:
    x = 'test'
    dataloaders[x] = torch.utils.data.DataLoader(image_datasets[x], batch_size=test_batch,
                                                 shuffle=True, num_workers=0)
    print('batch size: {}'.format(test_batch))
    t0 = time.time()
    test('test', torch.device("cuda:0"))
    pytorch_gpu_time = time.time() - t0
    print('{} seconds'.format(pytorch_gpu_time))
# Out:
# batch size: 2
# test data set: test
# /home/ccma/n1p1/home/ccma/Chilung/lab5-venv/lib/python3.5/site-packages/ipykernel_launcher.py:43: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.118
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 44.60714054107666 seconds
# batch size: 4
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.059
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 41.56234264373779 seconds
# batch size: 8
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.029
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 40.748273849487305 seconds
# batch size: 16
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.015
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 41.54971933364868 seconds
# batch size: 32
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.007
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 40.90515089035034 seconds
# batch size: 64
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.004
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 41.473981857299805 seconds
# batch size: 128
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.002
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 39.94637608528137 seconds
# batch size: 256
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.001
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 39.86449885368347 seconds

# %%
for test_batch in [2, 4, 8, 16, 32, 64, 128, 256]:
    x = 'test'
    dataloaders[x] = torch.utils.data.DataLoader(image_datasets[x], batch_size=test_batch,
                                                 shuffle=True, num_workers=0)
    print('batch size: {}'.format(test_batch))
    t0 = time.time()
    test('test', torch.device("cpu"))
    pytorch_cpu_time = time.time() - t0
    print('{} seconds'.format(pytorch_cpu_time))
# Out:
# batch size: 2
# test data set: test
# /home/ccma/n1p1/home/ccma/Chilung/lab5-venv/lib/python3.5/site-packages/ipykernel_launcher.py:43: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.118
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 240.50005960464478 seconds
# batch size: 4
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.059
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 229.77259731292725 seconds
# batch size: 8
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.029
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 223.50086998939514 seconds
# batch size: 16
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.015
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 224.91763544082642 seconds
# batch size: 32
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.007
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 223.45061016082764 seconds
# batch size: 64
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.004
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 217.49340987205505 seconds
# batch size: 128
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.002
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 217.05420923233032 seconds
# batch size: 256
# test data set: test
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.001
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 216.6092927455902 seconds

# %%
import torch.onnx
help(torch.onnx.export)
# Out:
# Help on function export in module torch.onnx:
#
# export(*args, **kwargs)

# %%
from torch.autograd import Variable
import torch
import torchvision
import onnx
import os
import time
from ngraph_onnx.onnx_importer.importer import import_onnx_model
import ngraph as ng
import numpy as np

def torch_to_ngraph(torch_model_name, batch_size = 1):
    dummy_input = torch.randn(batch_size, 3, 224, 224, device='cuda')
    #print(dummy_input.shape)
    model_resnet18 = torch.load(torch_model_name).cuda()
    torch.onnx.export(model_resnet18, dummy_input, 'resnet18.onnx',
                      export_params=True, verbose=False, training=False)
    onnx_filename = 'resnet18.onnx'
    onnx_resnet18 = onnx.load(onnx_filename)
    onnx.checker.check_model(onnx_resnet18)
    #print(onnx.helper.printable_graph(onnx_resnet18.graph))
    ng_models = import_onnx_model(onnx_resnet18)
    #print(ng_models)

    ng_model = ng_models[0]
    runtime = ng.runtime(backend_name='CPU')
    ngraph_resnet18 = runtime.computation(ng_model['output'], *ng_model['inputs'])
    return(ngraph_resnet18)

# %%
def test_ngraph(model, t_data):
    print('test data set: %s' %(t_data))
    
    device = torch.device("cpu")
    correct = 0
    total = 0
    running_loss = 0.0

    class_correct = list(0. for i in range(11))
    class_total = list(0. for i in range(11))

    with torch.no_grad():
        for data in dataloaders[t_data]:
            images, labels = data
 
            images = images.to(device)
            labels = labels.to(device)
            
            minus_amount = 0
            if(images.size() != torch.Size([test_batch, 3, 224, 224])):
                minus_amount = test_batch - list(images.size())[0]
                print('image size: {}, minus: {}'.format(list(images.size())[0], minus_amount))
                temp_images = torch.zeros([test_batch, 3, 224, 224])
                for i in range(list(images.size())[0]):
                    temp_images[i, :, :, :] = images[i, :, :, :]
                images = temp_images
                temp_labels = torch.zeros([test_batch], dtype=torch.long)
                for i in range(list(labels.size())[0]):
                    temp_labels[i] = labels[i]
                labels = temp_labels
           
            outputs = model(images)
            outputs = torch.from_numpy(outputs)
           
            _, predicted = torch.max(outputs, 1)
        
            total += labels.size(0) - minus_amount
            correct += (predicted == labels).sum().item()

            loss = criterion(outputs, labels)
            running_loss += loss.item()

            c = (predicted == labels).squeeze()

            for i in range(labels.size(0)):
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1

    print('Accuracy of the network on the %d test images: %.2f%%, and loss is: %.3f'
          % (total, 100 * correct / total, running_loss / total))

    for i in range(11):
        print('Accuracy of %5s : %2d %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))

# %%
test_batch = 64
x = 'test'
dataloaders[x] = torch.utils.data.DataLoader(image_datasets[x], batch_size=test_batch,
                                             shuffle=True, num_workers=0)
ngraph_model = torch_to_ngraph(torch_model_name = './model-lab5-pytorch-0.4.0-resnet18-food11-1544328065.9809835.pt',
                batch_size = test_batch)
t0 = time.time()
test_ngraph(ngraph_model, 'test')
print('{} seconds'.format(time.time() - t0))
# Out:
# test data set: test
# image size: 19, minus: 45
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.006
# Accuracy of Bread : 78 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 79.72860884666443 seconds

# %%
for test_batch in [2, 4, 8, 16, 32, 64, 128, 256]:
    x = 'test'
    dataloaders[x] = torch.utils.data.DataLoader(image_datasets[x], batch_size=test_batch,
                                                 shuffle=True, num_workers=0)
    ngraph_model = torch_to_ngraph(torch_model_name = './model-lab5-pytorch-0.4.0-resnet18-food11-1544328065.9809835.pt',
                                   batch_size = test_batch)
    print('batch size: {}'.format(test_batch))
    t0 = time.time()
    test_ngraph(ngraph_model, 'test')
    print('{} seconds'.format(time.time() - t0))
# Out:
# batch size: 2
# test data set: test
# image size: 1, minus: 1
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.119
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 165.80812788009644 seconds
# batch size: 4
# test data set: test
# image size: 3, minus: 1
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.060
# Accuracy of Bread : 88 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 136.33139610290527 seconds
# batch size: 8
# test data set: test
# image size: 3, minus: 5
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.031
# Accuracy of Bread : 87 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 114.26877498626709 seconds
# batch size: 16
# test data set: test
# image size: 3, minus: 13
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.017
# Accuracy of Bread : 85 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 92.89171290397644 seconds
# batch size: 32
# test data set: test
# image size: 19, minus: 13
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.009
# Accuracy of Bread : 85 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 83.50122857093811 seconds
# batch size: 64
# test data set: test
# image size: 19, minus: 45
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.006
# Accuracy of Bread : 78 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 79.37387299537659 seconds
# batch size: 128
# test data set: test
# image size: 19, minus: 109
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.005
# Accuracy of Bread : 68 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 76.24972867965698 seconds
# batch size: 256
# test data set: test
# image size: 19, minus: 237
# Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.004
# Accuracy of Bread : 53 %
# Accuracy of DairyProduct : 81 %
# Accuracy of Dessert : 97 %
# Accuracy of   Egg : 88 %
# Accuracy of Friedfood : 92 %
# Accuracy of  Meat : 91 %
# Accuracy of Noodles-Pasta : 92 %
# Accuracy of  Rice : 98 %
# Accuracy of Seafood : 98 %
# Accuracy of  Soup : 91 %
# Accuracy of Vegetable-Fruit : 97 %
# 76.82095408439636 seconds

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import matplotlib.animation as animation
import matplotlib.patches as mpatches

from torch.autograd import Variable
import torch
import math

import os
import sys
import re
from collections import OrderedDict

def test_result(fname):

    dictionary_acc = OrderedDict()
    dictionary_time = OrderedDict()
    
    with open(fname) as fp:  
        for cnt, line in enumerate(fp):
            print("Line {}: {}".format(cnt, line))
            # batch size: 2
            pattern = re.compile(r"batch size: (\d+)")
            match = pattern.match(line)
            if match:
                batch_size_str, = match.groups()
                print(batch_size_str)
                      
            # Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.004
            pattern = re.compile(r"Accuracy of the network on the (\d+) test images: (\d+.\d+)%, and loss is: (\d+.\d+)")
            match = pattern.match(line)
            if match:
                test_size_str, acc_str, loss_str = match.groups()
                print(test_size_str, acc_str, loss_str)

            # 76.6552894115448 seconds
            pattern = re.compile(r"(\d+.\d+) seconds")
            match = pattern.match(line)
            if match:
                time_str, = match.groups()
                print(time_str)
                print('batch: {:s}, acc: {:s}, time: {:s}'.
                      format(batch_size_str, acc_str, time_str))

                batch = int(math.log(int(batch_size_str), 2))
                acc = float("{:.2f}".format(float(acc_str)))
                time = float("{:.2f}".format(float(time_str)))
                
                dictionary_acc[batch] = acc
                dictionary_time[batch] = time
                    
    return dictionary_acc, dictionary_time

# %%
pytorch_gpu_acc, pytorch_gpu_time = test_result("pytorch-gpu-test-result.log")
pytorch_cpu_acc, pytorch_cpu_time = test_result("pytorch-cpu-test-result.log")
ngraph_acc, ngraph_time = test_result("ngraph-test-result.log")
# Out:
# Line 0: batch size: 2
#
# 2
# Line 1: test data set: test
#
# Line 2:
#
# Line 3: /home/ccma/n1p1/home/ccma/Chilung/lab5-venv/lib/python3.5/site-packages/ipykernel_launcher.py:43: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#
# Line 4:
#
# Line 5: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.118
#
# 3347 92.41 0.118
# Line 6: Accuracy of Bread : 88 %
#
# Line 7: Accuracy of DairyProduct : 81 %
#
# Line 8: Accuracy of Dessert : 97 %
#
# Line 9: Accuracy of   Egg : 88 %
#
# Line 10: Accuracy of Friedfood : 92 %
#
# Line 11: Accuracy of  Meat : 91 %
#
# Line 12: Accuracy of Noodles-Pasta : 92 %
#
# Line 13: Accuracy of  Rice : 98 %
#
# Line 14: Accuracy of Seafood : 98 %
#
# Line 15: Accuracy of  Soup : 91 %
#
# Line 16: Accuracy of Vegetable-Fruit : 97 %
#
# Line 17: 41.08022952079773 seconds
#
# 41.08022952079773
# batch: 2, acc: 92.41, time: 41.08022952079773
# Line 18: batch size: 4
#
# 4
# Line 19: test data set: test
#
# Line 20: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.059
#
# 3347 92.41 0.059
# Line 21: Accuracy of Bread : 88 %
#
# Line 22: Accuracy of DairyProduct : 81 %
#
# Line 23: Accuracy of Dessert : 97 %
#
# Line 24: Accuracy of   Egg : 88 %
#
# Line 25: Accuracy of Friedfood : 92 %
#
# Line 26: Accuracy of  Meat : 91 %
#
# Line 27: Accuracy of Noodles-Pasta : 92 %
#
# Line 28: Accuracy of  Rice : 98 %
#
# Line 29: Accuracy of Seafood : 98 %
#
# Line 30: Accuracy of  Soup : 91 %
#
# Line 31: Accuracy of Vegetable-Fruit : 97 %
#
# Line 32: 39.71622061729431 seconds
#
# 39.71622061729431
# batch: 4, acc: 92.41, time: 39.71622061729431
# Line 33: batch size: 8
#
# 8
# Line 34: test data set: test
#
# Line 35: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.029
#
# 3347 92.41 0.029
# Line 36: Accuracy of Bread : 88 %
#
# Line 37: Accuracy of DairyProduct : 81 %
#
# Line 38: Accuracy of Dessert : 97 %
#
# Line 39: Accuracy of   Egg : 88 %
#
# Line 40: Accuracy of Friedfood : 92 %
#
# Line 41: Accuracy of  Meat : 91 %
#
# Line 42: Accuracy of Noodles-Pasta : 92 %
#
# Line 43: Accuracy of  Rice : 98 %
#
# Line 44: Accuracy of Seafood : 98 %
#
# Line 45: Accuracy of  Soup : 91 %
#
# Line 46: Accuracy of Vegetable-Fruit : 97 %
#
# Line 47: 39.40698456764221 seconds
#
# 39.40698456764221
# batch: 8, acc: 92.41, time: 39.40698456764221
# Line 48: batch size: 16
#
# 16
# Line 49: test data set: test
#
# Line 50: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.015
#
# 3347 92.41 0.015
# Line 51: Accuracy of Bread : 88 %
#
# Line 52: Accuracy of DairyProduct : 81 %
#
# Line 53: Accuracy of Dessert : 97 %
#
# Line 54: Accuracy of   Egg : 88 %
#
# Line 55: Accuracy of Friedfood : 92 %
#
# Line 56: Accuracy of  Meat : 91 %
#
# Line 57: Accuracy of Noodles-Pasta : 92 %
#
# Line 58: Accuracy of  Rice : 98 %
#
# Line 59: Accuracy of Seafood : 98 %
#
# Line 60: Accuracy of  Soup : 91 %
#
# Line 61: Accuracy of Vegetable-Fruit : 97 %
#
# Line 62: 39.805410861968994 seconds
#
# 39.805410861968994
# batch: 16, acc: 92.41, time: 39.805410861968994
# Line 63: batch size: 32
#
# 32
# Line 64: test data set: test
#
# Line 65: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.007
#
# 3347 92.41 0.007
# Line 66: Accuracy of Bread : 88 %
#
# Line 67: Accuracy of DairyProduct : 81 %
#
# Line 68: Accuracy of Dessert : 97 %
#
# Line 69: Accuracy of   Egg : 88 %
#
# Line 70: Accuracy of Friedfood : 92 %
#
# Line 71: Accuracy of  Meat : 91 %
#
# Line 72: Accuracy of Noodles-Pasta : 92 %
#
# Line 73: Accuracy of  Rice : 98 %
#
# Line 74: Accuracy of Seafood : 98 %
#
# Line 75: Accuracy of  Soup : 91 %
#
# Line 76: Accuracy of Vegetable-Fruit : 97 %
#
# Line 77: 38.876230001449585 seconds
#
# 38.876230001449585
# batch: 32, acc: 92.41, time: 38.876230001449585
# Line 78: batch size: 64
#
# 64
# Line 79: test data set: test
#
# Line 80: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.004
#
# 3347 92.41 0.004
# Line 81: Accuracy of Bread : 88 %
#
# Line 82: Accuracy of DairyProduct : 81 %
#
# Line 83: Accuracy of Dessert : 97 %
#
# Line 84: Accuracy of   Egg : 88 %
#
# Line 85: Accuracy of Friedfood : 92 %
#
# Line 86: Accuracy of  Meat : 91 %
#
# Line 87: Accuracy of Noodles-Pasta : 92 %
#
# Line 88: Accuracy of  Rice : 98 %
#
# Line 89: Accuracy of Seafood : 98 %
#
# Line 90: Accuracy of  Soup : 91 %
#
# Line 91: Accuracy of Vegetable-Fruit : 97 %
#
# Line 92: 39.156503200531006 seconds
#
# 39.156503200531006
# batch: 64, acc: 92.41, time: 39.156503200531006
# Line 93: batch size: 128
#
# 128
# Line 94: test data set: test
#
# Line 95: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.002
#
# 3347 92.41 0.002
# Line 96: Accuracy of Bread : 88 %
#
# Line 97: Accuracy of DairyProduct : 81 %
#
# Line 98: Accuracy of Dessert : 97 %
#
# Line 99: Accuracy of   Egg : 88 %
#
# Line 100: Accuracy of Friedfood : 92 %
#
# Line 101: Accuracy of  Meat : 91 %
#
# Line 102: Accuracy of Noodles-Pasta : 92 %
#
# Line 103: Accuracy of  Rice : 98 %
#
# Line 104: Accuracy of Seafood : 98 %
#
# Line 105: Accuracy of  Soup : 91 %
#
# Line 106: Accuracy of Vegetable-Fruit : 97 %
#
# Line 107: 39.112802267074585 seconds
#
# 39.112802267074585
# batch: 128, acc: 92.41, time: 39.112802267074585
# Line 108: batch size: 256
#
# 256
# Line 109: test data set: test
#
# Line 110: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.001
#
# 3347 92.41 0.001
# Line 111: Accuracy of Bread : 88 %
#
# Line 112: Accuracy of DairyProduct : 81 %
#
# Line 113: Accuracy of Dessert : 97 %
#
# Line 114: Accuracy of   Egg : 88 %
#
# Line 115: Accuracy of Friedfood : 92 %
#
# Line 116: Accuracy of  Meat : 91 %
#
# Line 117: Accuracy of Noodles-Pasta : 92 %
#
# Line 118: Accuracy of  Rice : 98 %
#
# Line 119: Accuracy of Seafood : 98 %
#
# Line 120: Accuracy of  Soup : 91 %
#
# Line 121: Accuracy of Vegetable-Fruit : 97 %
#
# Line 122: 39.5123827457428 seconds
#
# 39.5123827457428
# batch: 256, acc: 92.41, time: 39.5123827457428
# Line 123:
#
# Line 0: batch size: 2
#
# 2
# Line 1: test data set: test
#
# Line 2:
#
# Line 3: /home/ccma/n1p1/home/ccma/Chilung/lab5-venv/lib/python3.5/site-packages/ipykernel_launcher.py:43: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#
# Line 4:
#
# Line 5: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.118
#
# 3347 92.41 0.118
# Line 6: Accuracy of Bread : 88 %
#
# Line 7: Accuracy of DairyProduct : 81 %
#
# Line 8: Accuracy of Dessert : 97 %
#
# Line 9: Accuracy of   Egg : 88 %
#
# Line 10: Accuracy of Friedfood : 92 %
#
# Line 11: Accuracy of  Meat : 91 %
#
# Line 12: Accuracy of Noodles-Pasta : 92 %
#
# Line 13: Accuracy of  Rice : 98 %
#
# Line 14: Accuracy of Seafood : 98 %
#
# Line 15: Accuracy of  Soup : 91 %
#
# Line 16: Accuracy of Vegetable-Fruit : 97 %
#
# Line 17: 247.47320199012756 seconds
#
# 247.47320199012756
# batch: 2, acc: 92.41, time: 247.47320199012756
# Line 18: batch size: 4
#
# 4
# Line 19: test data set: test
#
# Line 20: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.059
#
# 3347 92.41 0.059
# Line 21: Accuracy of Bread : 88 %
#
# Line 22: Accuracy of DairyProduct : 81 %
#
# Line 23: Accuracy of Dessert : 97 %
#
# Line 24: Accuracy of   Egg : 88 %
#
# Line 25: Accuracy of Friedfood : 92 %
#
# Line 26: Accuracy of  Meat : 91 %
#
# Line 27: Accuracy of Noodles-Pasta : 92 %
#
# Line 28: Accuracy of  Rice : 98 %
#
# Line 29: Accuracy of Seafood : 98 %
#
# Line 30: Accuracy of  Soup : 91 %
#
# Line 31: Accuracy of Vegetable-Fruit : 97 %
#
# Line 32: 237.8782229423523 seconds
#
# 237.8782229423523
# batch: 4, acc: 92.41, time: 237.8782229423523
# Line 33: batch size: 8
#
# 8
# Line 34: test data set: test
#
# Line 35: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.029
#
# 3347 92.41 0.029
# Line 36: Accuracy of Bread : 88 %
#
# Line 37: Accuracy of DairyProduct : 81 %
#
# Line 38: Accuracy of Dessert : 97 %
#
# Line 39: Accuracy of   Egg : 88 %
#
# Line 40: Accuracy of Friedfood : 92 %
#
# Line 41: Accuracy of  Meat : 91 %
#
# Line 42: Accuracy of Noodles-Pasta : 92 %
#
# Line 43: Accuracy of  Rice : 98 %
#
# Line 44: Accuracy of Seafood : 98 %
#
# Line 45: Accuracy of  Soup : 91 %
#
# Line 46: Accuracy of Vegetable-Fruit : 97 %
#
# Line 47: 231.3554995059967 seconds
#
# 231.3554995059967
# batch: 8, acc: 92.41, time: 231.3554995059967
# Line 48: batch size: 16
#
# 16
# Line 49: test data set: test
#
# Line 50: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.015
#
# 3347 92.41 0.015
# Line 51: Accuracy of Bread : 88 %
#
# Line 52: Accuracy of DairyProduct : 81 %
#
# Line 53: Accuracy of Dessert : 97 %
#
# Line 54: Accuracy of   Egg : 88 %
#
# Line 55: Accuracy of Friedfood : 92 %
#
# Line 56: Accuracy of  Meat : 91 %
#
# Line 57: Accuracy of Noodles-Pasta : 92 %
#
# Line 58: Accuracy of  Rice : 98 %
#
# Line 59: Accuracy of Seafood : 98 %
#
# Line 60: Accuracy of  Soup : 91 %
#
# Line 61: Accuracy of Vegetable-Fruit : 97 %
#
# Line 62: 229.0734326839447 seconds
#
# 229.0734326839447
# batch: 16, acc: 92.41, time: 229.0734326839447
# Line 63: batch size: 32
#
# 32
# Line 64: test data set: test
#
# Line 65: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.007
#
# 3347 92.41 0.007
# Line 66: Accuracy of Bread : 88 %
#
# Line 67: Accuracy of DairyProduct : 81 %
#
# Line 68: Accuracy of Dessert : 97 %
#
# Line 69: Accuracy of   Egg : 88 %
#
# Line 70: Accuracy of Friedfood : 92 %
#
# Line 71: Accuracy of  Meat : 91 %
#
# Line 72: Accuracy of Noodles-Pasta : 92 %
#
# Line 73: Accuracy of  Rice : 98 %
#
# Line 74: Accuracy of Seafood : 98 %
#
# Line 75: Accuracy of  Soup : 91 %
#
# Line 76: Accuracy of Vegetable-Fruit : 97 %
#
# Line 77: 227.59535932540894 seconds
#
# 227.59535932540894
# batch: 32, acc: 92.41, time: 227.59535932540894
# Line 78: batch size: 64
#
# 64
# Line 79: test data set: test
#
# Line 80: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.004
#
# 3347 92.41 0.004
# Line 81: Accuracy of Bread : 88 %
#
# Line 82: Accuracy of DairyProduct : 81 %
#
# Line 83: Accuracy of Dessert : 97 %
#
# Line 84: Accuracy of   Egg : 88 %
#
# Line 85: Accuracy of Friedfood : 92 %
#
# Line 86: Accuracy of  Meat : 91 %
#
# Line 87: Accuracy of Noodles-Pasta : 92 %
#
# Line 88: Accuracy of  Rice : 98 %
#
# Line 89: Accuracy of Seafood : 98 %
#
# Line 90: Accuracy of  Soup : 91 %
#
# Line 91: Accuracy of Vegetable-Fruit : 97 %
#
# Line 92: 218.346853017807 seconds
#
# 218.346853017807
# batch: 64, acc: 92.41, time: 218.346853017807
# Line 93: batch size: 128
#
# 128
# Line 94: test data set: test
#
# Line 95: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.002
#
# 3347 92.41 0.002
# Line 96: Accuracy of Bread : 88 %
#
# Line 97: Accuracy of DairyProduct : 81 %
#
# Line 98: Accuracy of Dessert : 97 %
#
# Line 99: Accuracy of   Egg : 88 %
#
# Line 100: Accuracy of Friedfood : 92 %
#
# Line 101: Accuracy of  Meat : 91 %
#
# Line 102: Accuracy of Noodles-Pasta : 92 %
#
# Line 103: Accuracy of  Rice : 98 %
#
# Line 104: Accuracy of Seafood : 98 %
#
# Line 105: Accuracy of  Soup : 91 %
#
# Line 106: Accuracy of Vegetable-Fruit : 97 %
#
# Line 107: 218.24231338500977 seconds
#
# 218.24231338500977
# batch: 128, acc: 92.41, time: 218.24231338500977
# Line 108: batch size: 256
#
# 256
# Line 109: test data set: test
#
# Line 110: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.001
#
# 3347 92.41 0.001
# Line 111: Accuracy of Bread : 88 %
#
# Line 112: Accuracy of DairyProduct : 81 %
#
# Line 113: Accuracy of Dessert : 97 %
#
# Line 114: Accuracy of   Egg : 88 %
#
# Line 115: Accuracy of Friedfood : 92 %
#
# Line 116: Accuracy of  Meat : 91 %
#
# Line 117: Accuracy of Noodles-Pasta : 92 %
#
# Line 118: Accuracy of  Rice : 98 %
#
# Line 119: Accuracy of Seafood : 98 %
#
# Line 120: Accuracy of  Soup : 91 %
#
# Line 121: Accuracy of Vegetable-Fruit : 97 %
#
# Line 122: 221.07516622543335 seconds
#
# 221.07516622543335
# batch: 256, acc: 92.41, time: 221.07516622543335
# Line 123:
#
# Line 0: batch size: 2
#
# 2
# Line 1: test data set: test
#
# Line 2: image size: 1, minus: 1
#
# Line 3: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.119
#
# 3347 92.41 0.119
# Line 4: Accuracy of Bread : 88 %
#
# Line 5: Accuracy of DairyProduct : 81 %
#
# Line 6: Accuracy of Dessert : 97 %
#
# Line 7: Accuracy of   Egg : 88 %
#
# Line 8: Accuracy of Friedfood : 92 %
#
# Line 9: Accuracy of  Meat : 91 %
#
# Line 10: Accuracy of Noodles-Pasta : 92 %
#
# Line 11: Accuracy of  Rice : 98 %
#
# Line 12: Accuracy of Seafood : 98 %
#
# Line 13: Accuracy of  Soup : 91 %
#
# Line 14: Accuracy of Vegetable-Fruit : 97 %
#
# Line 15: 174.36557960510254 seconds
#
# 174.36557960510254
# batch: 2, acc: 92.41, time: 174.36557960510254
# Line 16: batch size: 4
#
# 4
# Line 17: test data set: test
#
# Line 18: image size: 3, minus: 1
#
# Line 19: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.060
#
# 3347 92.41 0.060
# Line 20: Accuracy of Bread : 88 %
#
# Line 21: Accuracy of DairyProduct : 81 %
#
# Line 22: Accuracy of Dessert : 97 %
#
# Line 23: Accuracy of   Egg : 88 %
#
# Line 24: Accuracy of Friedfood : 92 %
#
# Line 25: Accuracy of  Meat : 91 %
#
# Line 26: Accuracy of Noodles-Pasta : 92 %
#
# Line 27: Accuracy of  Rice : 98 %
#
# Line 28: Accuracy of Seafood : 98 %
#
# Line 29: Accuracy of  Soup : 91 %
#
# Line 30: Accuracy of Vegetable-Fruit : 97 %
#
# Line 31: 128.19496893882751 seconds
#
# 128.19496893882751
# batch: 4, acc: 92.41, time: 128.19496893882751
# Line 32: batch size: 8
#
# 8
# Line 33: test data set: test
#
# Line 34: image size: 3, minus: 5
#
# Line 35: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.031
#
# 3347 92.41 0.031
# Line 36: Accuracy of Bread : 87 %
#
# Line 37: Accuracy of DairyProduct : 81 %
#
# Line 38: Accuracy of Dessert : 97 %
#
# Line 39: Accuracy of   Egg : 88 %
#
# Line 40: Accuracy of Friedfood : 92 %
#
# Line 41: Accuracy of  Meat : 91 %
#
# Line 42: Accuracy of Noodles-Pasta : 92 %
#
# Line 43: Accuracy of  Rice : 98 %
#
# Line 44: Accuracy of Seafood : 98 %
#
# Line 45: Accuracy of  Soup : 91 %
#
# Line 46: Accuracy of Vegetable-Fruit : 97 %
#
# Line 47: 109.84347105026245 seconds
#
# 109.84347105026245
# batch: 8, acc: 92.41, time: 109.84347105026245
# Line 48: batch size: 16
#
# 16
# Line 49: test data set: test
#
# Line 50: image size: 3, minus: 13
#
# Line 51: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.017
#
# 3347 92.41 0.017
# Line 52: Accuracy of Bread : 85 %
#
# Line 53: Accuracy of DairyProduct : 81 %
#
# Line 54: Accuracy of Dessert : 97 %
#
# Line 55: Accuracy of   Egg : 88 %
#
# Line 56: Accuracy of Friedfood : 92 %
#
# Line 57: Accuracy of  Meat : 91 %
#
# Line 58: Accuracy of Noodles-Pasta : 92 %
#
# Line 59: Accuracy of  Rice : 98 %
#
# Line 60: Accuracy of Seafood : 98 %
#
# Line 61: Accuracy of  Soup : 91 %
#
# Line 62: Accuracy of Vegetable-Fruit : 97 %
#
# Line 63: 89.33163356781006 seconds
#
# 89.33163356781006
# batch: 16, acc: 92.41, time: 89.33163356781006
# Line 64: batch size: 32
#
# 32
# Line 65: test data set: test
#
# Line 66: image size: 19, minus: 13
#
# Line 67: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.009
#
# 3347 92.41 0.009
# Line 68: Accuracy of Bread : 85 %
#
# Line 69: Accuracy of DairyProduct : 81 %
#
# Line 70: Accuracy of Dessert : 97 %
#
# Line 71: Accuracy of   Egg : 88 %
#
# Line 72: Accuracy of Friedfood : 92 %
#
# Line 73: Accuracy of  Meat : 91 %
#
# Line 74: Accuracy of Noodles-Pasta : 92 %
#
# Line 75: Accuracy of  Rice : 98 %
#
# Line 76: Accuracy of Seafood : 98 %
#
# Line 77: Accuracy of  Soup : 91 %
#
# Line 78: Accuracy of Vegetable-Fruit : 97 %
#
# Line 79: 77.84082961082458 seconds
#
# 77.84082961082458
# batch: 32, acc: 92.41, time: 77.84082961082458
# Line 80: batch size: 64
#
# 64
# Line 81: test data set: test
#
# Line 82: image size: 19, minus: 45
#
# Line 83: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.006
#
# 3347 92.41 0.006
# Line 84: Accuracy of Bread : 78 %
#
# Line 85: Accuracy of DairyProduct : 81 %
#
# Line 86: Accuracy of Dessert : 97 %
#
# Line 87: Accuracy of   Egg : 88 %
#
# Line 88: Accuracy of Friedfood : 92 %
#
# Line 89: Accuracy of  Meat : 91 %
#
# Line 90: Accuracy of Noodles-Pasta : 92 %
#
# Line 91: Accuracy of  Rice : 98 %
#
# Line 92: Accuracy of Seafood : 98 %
#
# Line 93: Accuracy of  Soup : 91 %
#
# Line 94: Accuracy of Vegetable-Fruit : 97 %
#
# Line 95: 73.42277765274048 seconds
#
# 73.42277765274048
# batch: 64, acc: 92.41, time: 73.42277765274048
# Line 96: batch size: 128
#
# 128
# Line 97: test data set: test
#
# Line 98: image size: 19, minus: 109
#
# Line 99: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.005
#
# 3347 92.41 0.005
# Line 100: Accuracy of Bread : 68 %
#
# Line 101: Accuracy of DairyProduct : 81 %
#
# Line 102: Accuracy of Dessert : 97 %
#
# Line 103: Accuracy of   Egg : 88 %
#
# Line 104: Accuracy of Friedfood : 92 %
#
# Line 105: Accuracy of  Meat : 91 %
#
# Line 106: Accuracy of Noodles-Pasta : 92 %
#
# Line 107: Accuracy of  Rice : 98 %
#
# Line 108: Accuracy of Seafood : 98 %
#
# Line 109: Accuracy of  Soup : 91 %
#
# Line 110: Accuracy of Vegetable-Fruit : 97 %
#
# Line 111: 75.20388603210449 seconds
#
# 75.20388603210449
# batch: 128, acc: 92.41, time: 75.20388603210449
# Line 112: batch size: 256
#
# 256
# Line 113: test data set: test
#
# Line 114: image size: 19, minus: 237
#
# Line 115: Accuracy of the network on the 3347 test images: 92.41%, and loss is: 0.004
#
# 3347 92.41 0.004
# Line 116: Accuracy of Bread : 53 %
#
# Line 117: Accuracy of DairyProduct : 81 %
#
# Line 118: Accuracy of Dessert : 97 %
#
# Line 119: Accuracy of   Egg : 88 %
#
# Line 120: Accuracy of Friedfood : 92 %
#
# Line 121: Accuracy of  Meat : 91 %
#
# Line 122: Accuracy of Noodles-Pasta : 92 %
#
# Line 123: Accuracy of  Rice : 98 %
#
# Line 124: Accuracy of Seafood : 98 %
#
# Line 125: Accuracy of  Soup : 91 %
#
# Line 126: Accuracy of Vegetable-Fruit : 97 %
#
# Line 127: 76.6552894115448 seconds
#
# 76.6552894115448
# batch: 256, acc: 92.41, time: 76.6552894115448
# Line 128:

# %%
import matplotlib.pyplot as plt
import itertools

def show_test_result(pytorch_gpu_acc, pytorch_gpu_time,
                     pytorch_cpu_acc, pytorch_cpu_time,
                     ngraph_acc, ngraph_time):
    
    print('Pytorch GPU Inference Time')
    print(pytorch_gpu_time)
    print('Pytorch GPU Accuracy')
    print(pytorch_gpu_acc)
    print('Pytorch CPU Inference Time')
    print(pytorch_cpu_time)
    print('Pytorch CPU Accuracy')
    print(pytorch_cpu_acc)
    print('nGraph Inference Time')
    print(ngraph_time)
    print('nGraph Accuracy')
    print(ngraph_acc)
        
    fig, ax1 = plt.subplots()

    fig.set_figheight(20)
    fig.set_figwidth(20)

    ax1.set_title('nGraph Inference Accuracy and Inference Time', fontsize=20)

    ax2 = ax1.twinx()
    ax2.figure.figsize=(120,120)
    
    l1, = ax1.plot(list(pytorch_gpu_time.keys()), list(pytorch_gpu_time.values()), 'r--')
    for i, j in zip(list(pytorch_gpu_time.keys()), list(pytorch_gpu_time.values())):
        ax1.annotate('%s' %j, xy=(i, j), xycoords='data',
                     xytext=(-10, 20), textcoords='offset points', color='r', fontsize=20)
    
    l2, = ax1.plot(list(pytorch_cpu_time.keys()), list(pytorch_cpu_time.values()), 'g--')
    for i, j in zip(list(pytorch_cpu_time.keys()), list(pytorch_cpu_time.values())):
        ax1.annotate('%s' %j, xy=(i, j), xycoords='data',
                     xytext=(-10, 20), textcoords='offset points', color='g', fontsize=20)
    
    l3, = ax1.plot(list(ngraph_time.keys()), list(ngraph_time.values()), 'b--')
    for i, j in zip(list(ngraph_time.keys()), list(ngraph_time.values())):
        ax1.annotate('%s' %j, xy=(i, j), xycoords='data',
                     xytext=(-10, 20), textcoords='offset points', color='b', fontsize=20)
    
    l4, = ax2.plot(list(pytorch_gpu_acc.keys()), list(pytorch_gpu_acc.values()), 'b-')
    for i, j in zip(list(pytorch_gpu_acc.keys()), list(pytorch_gpu_acc.values())):
        ax2.annotate('%s' %j, xy=(i, j), xycoords='data',
                     xytext=(-10, -20), textcoords='offset points', color='b', fontsize=20)
    
    l5, = ax2.plot(list(pytorch_cpu_acc.keys()), list(pytorch_cpu_acc.values()), 'b-')
    for i, j in zip(list(pytorch_cpu_acc.keys()), list(pytorch_cpu_acc.values())):
        ax2.annotate('%s' %j, xy=(i, j), xycoords='data',
                     xytext=(-10, -20), textcoords='offset points', color='b', fontsize=20)
    
    l6, = ax2.plot(list(ngraph_acc.keys()), list(ngraph_acc.values()), 'b-')
    for i, j in zip(list(ngraph_acc.keys()), list(ngraph_acc.values())):
        ax2.annotate('%s' %j, xy=(i, j), xycoords='data',
                     xytext=(-10, -20), textcoords='offset points', color='b', fontsize=20)
    
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)

    ax1.tick_params(axis='both', which='major', labelsize=20)
    ax2.tick_params(axis='y', which='major', labelsize=20)

    ax1.set_xlabel('Batch Size (power of 2)', fontsize=20)
    ax1.set_ylabel('Second', fontsize=20, color='r')
    ax2.set_ylabel('Accuracy (%)', fontsize=20, color='b')
    
    ax2.set(ylim=[0, 100])
    
    ax1.grid(axis='both', which='both')
    plt.legend(handles=[l1, l2, l3, l4, l5, l6],
               labels=['Pytorch GPU Inference Time', 'Pytorch CPU Inference Time', 'nGraph Inference Time',
                       'Pytorch GPU Accuracy', 'Pytorch CPU Accuracy','nGraph Accuracy'],
               fontsize=20, loc='right')

    plt.show()

# %%
show_test_result(pytorch_gpu_acc, pytorch_gpu_time,
                     pytorch_cpu_acc, pytorch_cpu_time,
                     ngraph_acc, ngraph_time)
# Out:
# Pytorch GPU Inference Time
# OrderedDict([(1, 41.08), (2, 39.72), (3, 39.41), (4, 39.81), (5, 38.88), (6, 39.16), (7, 39.11), (8, 39.51)])
# Pytorch GPU Accuracy
# OrderedDict([(1, 92.41), (2, 92.41), (3, 92.41), (4, 92.41), (5, 92.41), (6, 92.41), (7, 92.41), (8, 92.41)])
# Pytorch CPU Inference Time
# OrderedDict([(1, 247.47), (2, 237.88), (3, 231.36), (4, 229.07), (5, 227.6), (6, 218.35), (7, 218.24), (8, 221.08)])
# Pytorch CPU Accuracy
# OrderedDict([(1, 92.41), (2, 92.41), (3, 92.41), (4, 92.41), (5, 92.41), (6, 92.41), (7, 92.41), (8, 92.41)])
# nGraph Inference Time
# OrderedDict([(1, 174.37), (2, 128.19), (3, 109.84), (4, 89.33), (5, 77.84), (6, 73.42), (7, 75.2), (8, 76.66)])
# nGraph Accuracy
# OrderedDict([(1, 92.41), (2, 92.41), (3, 92.41), (4, 92.41), (5, 92.41), (6, 92.41), (7, 92.41), (8, 92.41)])
